# %%
include("AuxiliaryFunctions/BornModel.jl")
include("AuxiliaryFunctions/Plotting.jl")
include("AuxiliaryFunctions/NoiseAuxiliaryFunctions.jl")

import .BornModel as BM
import .Plotting as P
import .NoiseAuxiliaryFunctions as NAF

using Plots, Plots.PlotMeasures
using DifferentialEquations
using BifurcationKit, Parameters
using Statistics
using KernelDensity
# Out:
# WARNING: using Plots.wrap in module BifurcationKit conflicts with an existing identifier.
# ┌ Warning: Error requiring `KrylovKit` from `LinearSolve`
# │   exception = (LoadError("C:\\Users\\kvdhe\\.julia\\packages\\LinearSolve\\qCLK7\\ext\\LinearSolveKrylovKitExt.jl", 1, ArgumentError("Package LinearSolve does not have KrylovKit in its dependencies:\n- You may have a partially installed environment. Try `Pkg.instantiate()`\n  to ensure all packages in the environment are installed.\n- Or, if you have LinearSolve checked out for development and have\n  added KrylovKit as a dependency but haven't updated your primary\n  environment's manifest file, try `Pkg.resolve()`.\n- Otherwise you may need to report an issue with LinearSolve")), Union{Ptr{Nothing}, Base.InterpreterIP}[Ptr{Nothing} @0x00000192f4ddab94, Ptr{Nothing} @0x00000192f4ddae0a, Ptr{Nothing} @0x00007ffa578d6a24, Ptr{Nothing} @0x00007ffa578d861e, Ptr{Nothing} @0x00007ffa578d7ddc, Ptr{Nothing} @0x00007ffa578d7f96, Ptr{Nothing} @0x00007ffa578d920e, Ptr{Nothing} @0x00007ffa245d2aba, Ptr{Nothing} @0x00007ffa24423b02, Ptr{Nothing} @0x00007ffa23cddfd6, Ptr{Nothing} @0x00007ffa23cddff5, Ptr{Nothing} @0x00007ffa578a9c2a, Ptr{Nothing} @0x00000192f4e4562f, Ptr{Nothing} @0x00000192f4e45656, Ptr{Nothing} @0x00007ffa578b93ca, Ptr{Nothing} @0x00007ffa578b8e0a, Ptr{Nothing} @0x00007ffa578b9876, Ptr{Nothing} @0x00007ffa578ba649, Base.InterpreterIP in top-level CodeInfo for LinearSolve at statement 15, Ptr{Nothing} @0x00007ffa578d772e, Ptr{Nothing} @0x00007ffa578d920e, Ptr{Nothing} @0x00000192f4e4559f, Ptr{Nothing} @0x00000192f4e455c3, Ptr{Nothing} @0x00007ffa578b93ca, Ptr{Nothing} @0x00007ffa578b8e0a, Ptr{Nothing} @0x00007ffa578b9b79, Ptr{Nothing} @0x00007ffa578b9e1f, Ptr{Nothing} @0x00007ffa578ba2dc, Base.InterpreterIP in MethodInstance for Requires.err(::Any, ::Module, ::String, ::String, ::Any) at statement 4, Ptr{Nothing} @0x00000192f4e454e5, Ptr{Nothing} @0x00000192f4e45503, Ptr{Nothing} @0x00007ffa578b93ca, Ptr{Nothing} @0x00007ffa578b8e0a, Ptr{Nothing} @0x00007ffa578b9b79, Ptr{Nothing} @0x00007ffa578b9e1f, Ptr{Nothing} @0x00007ffa578ba2dc, Base.InterpreterIP in MethodInstance for Requires.withpath(::Any, ::String) at statement 10, Ptr{Nothing} @0x00000192f4e453e9, Ptr{Nothing} @0x00000192f4e45463, Ptr{Nothing} @0x00007ffa578b93ca, Ptr{Nothing} @0x00007ffa578b8e0a, Ptr{Nothing} @0x00007ffa578b9876, Ptr{Nothing} @0x00007ffa578ba2dc, Base.InterpreterIP in MethodInstance for Requires.listenpkg(::Any, ::Base.PkgId) at statement 3, Ptr{Nothing} @0x00000192f4e4506c, Ptr{Nothing} @0x00000192f4e45333, Ptr{Nothing} @0x00007ffa578d6fd3, Ptr{Nothing} @0x00007ffa578cc430, Ptr{Nothing} @0x00000192f4dcbd92, Ptr{Nothing} @0x00000192f4dcd36d, Ptr{Nothing} @0x00000192f4dd46bc, Ptr{Nothing} @0x00000192f4dd771a, Ptr{Nothing} @0x00000192f4dda17c, Ptr{Nothing} @0x00000192f4dda84b, Ptr{Nothing} @0x00000192f4ddae0a, Ptr{Nothing} @0x00007ffa578d6a24, Ptr{Nothing} @0x00007ffa578d861e, Ptr{Nothing} @0x00007ffa578d7ddc, Ptr{Nothing} @0x00007ffa578d7f96, Ptr{Nothing} @0x00007ffa578d920e, Ptr{Nothing} @0x00007ffa245d2aba, Ptr{Nothing} @0x00007ffa24423b02, Ptr{Nothing} @0x00000192f4e0d467, Ptr{Nothing} @0x00000192f4e0d486, Ptr{Nothing} @0x00007ffa578b93ca, Ptr{Nothing} @0x00007ffa578b8e0a, Ptr{Nothing} @0x00007ffa578b9876, Ptr{Nothing} @0x00007ffa578ba649, Base.InterpreterIP in top-level CodeInfo for Main at statement 0, Ptr{Nothing} @0x00007ffa578d772e, Ptr{Nothing} @0x00007ffa578d7f96, Ptr{Nothing} @0x00007ffa578d920e, Ptr{Nothing} @0x00000192f4e0d0e9, Ptr{Nothing} @0x00000192f4e0d3fa, Ptr{Nothing} @0x00000192f4e0a159, Ptr{Nothing} @0x00000192f4e0b18a, Ptr{Nothing} @0x00007ffa578a9c2a, Ptr{Nothing} @0x00000192f4dfd722, Ptr{Nothing} @0x00000192f4e07652, Ptr{Nothing} @0x00000192f4e07673, Ptr{Nothing} @0x00007ffa578be9ce])
# └ @ Requires C:\Users\kvdhe\.julia\packages\Requires\Z8rfN\src\require.jl:51

# %%
# integration settings

spinup = 10
n_years = 5000 + spinup #5000

seed = 111
# Out:
# 111

# %%
noisevec = [0, BM.nondimensional_S(0.5), 0]

pars_F05_S35_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(35.), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(6.), Tamp = BM.nondimensional_T(-273.15 + 8.),
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(0.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F05_S35_σS05 = NAF.integration(pars_F05_S35_σS05, noisevec, seed, n_years, spinup)

pars_F1_S35_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(35.), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(6.), Tamp = BM.nondimensional_T(-273.15 + 8.),
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F1_S35_σS05 = NAF.integration(pars_F1_S35_σS05, noisevec, seed, n_years, spinup)

pars_F15_S35_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(35.), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(6.), Tamp = BM.nondimensional_T(-273.15 + 8.),
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F15_S35_σS05 = NAF.integration(pars_F15_S35_σS05, noisevec, seed, n_years, spinup)

pars_F05_S3475_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(34.75), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(6.), Tamp = BM.nondimensional_T(-273.15 + 8.),
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(0.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F05_S3475_σS05 = NAF.integration(pars_F05_S3475_σS05, noisevec, seed, n_years, spinup)

pars_F1_S3475_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(34.75), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(6.), Tamp = BM.nondimensional_T(-273.15 + 8.),
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F1_S3475_σS05 = NAF.integration(pars_F1_S3475_σS05, noisevec, seed, n_years, spinup)

pars_F15_S3475_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(34.75), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(6.), Tamp = BM.nondimensional_T(-273.15 + 8.),
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F15_S3475_σS05 = NAF.integration(pars_F15_S3475_σS05, noisevec, seed, n_years, spinup)
# Out:
# (M_yearly = [23.20314779565665, 21.271895578103784, 20.522429140011575, 20.174727246726253, 20.067425302125255, 19.971863555962614, 19.92046922773149, 19.887882027137508, 19.87220481806122, 19.85125680853672  …  20.556160760502483, 20.135782117045135, 19.97954413707557, 19.948808123906776, 19.915507951340505, 19.909272821913582, 19.892317846941662, 19.88121212376012, 19.932771215969705, 19.928377464363624], ratio = 0.365, below = [13, 8, 12, 21, 15, 54, 10, 5, 9, 6  …  19, 8, 3, 7, 30, 13, 23, 34, 33, 11], above = [1, 5, 18, 1, 1, 3, 18, 2, 23, 1  …  9, 3, 3, 12, 26, 3, 12, 19, 9, 4])

# %%
ylimits12 = (18, 30)
ylimits3 = nothing
xlimits12 = (0, 0.5)
xlimits3 = (0, 30)

p_F05_S35_σS05 = NAF.plot_integration_PDF(output_F05_S35_σS05, "A", "a)", "b)", "c)", xlimits12, xlimits3, ylimits12, (0, 0.4), 0:0.1:0.4)
p_F1_S35_σS05 = NAF.plot_integration_PDF(output_F1_S35_σS05, "B ", "d)", "e)", "f)", xlimits12, xlimits3, ylimits12, (0, 0.3), 0:0.1:0.4)
p_F15_S35_σS05 = NAF.plot_integration_PDF(output_F15_S35_σS05, "C ", "g)", "h)", "i)", xlimits12, xlimits3, ylimits12, (0, 0.15), 0:0.05:0.15)
p_F05_S3475_σS05 = NAF.plot_integration_PDF(output_F05_S3475_σS05, "D ", "j)", "k)", "l)", xlimits12, xlimits3, ylimits12, (0, 0.3), 0:0.1:0.3)
p_F1_S3475_σS05 = NAF.plot_integration_PDF(output_F1_S3475_σS05, "E ", "m)", "n)", "o)", xlimits12, xlimits3, ylimits12, (0, 0.15), 0:0.05:0.15)
p_F15_S3475_σS05 = NAF.plot_integration_PDF(output_F15_S3475_σS05, "F ", "p)", "q)", "r)", xlimits12, xlimits3, ylimits12, (0, 0.06), 0:0.02:0.6)

plot(p_F05_S35_σS05, p_F1_S35_σS05, p_F15_S35_σS05, p_F05_S3475_σS05, p_F1_S3475_σS05, p_F15_S3475_σS05, layout = (6, 1), 
    titlefonthalign = :left,    
    titlefontsize = 14,
    size = (width = 1000, height = 1500),
    left_margin = 30px, right_margin = 20px,
    dpi = 300)

savefig("Figures/stochasticsimulation-nonautonomous.pdf")
# Out:
# "c:\\Users\\kvdhe\\Documents\\a. Studie\\6 - MSc 2\\Thesis\\Paper\\Code\\Figures\\stochasticsimulation-nonautonomous.pdf"

# %% [markdown]
# ## State ratios

# %%
print("Ratio A (F = 0.5, S2 = 35)   : $(output_F05_S35_σS05.ratio) \n")
print("Ratio B (F = 1  , S2 = 35)   : $(output_F1_S35_σS05.ratio) \n")
print("Ratio C (F = 1.5, S2 = 35)   : $(output_F15_S35_σS05.ratio) \n")
print("Ratio D (F = 0.5, S2 = 34.75): $(output_F05_S3475_σS05.ratio) \n")
print("Ratio E (F = 1  , S2 = 34.75): $(output_F1_S3475_σS05.ratio) \n")
print("Ratio F (F = 1  , S2 = 34.75): $(output_F15_S3475_σS05.ratio) \n")
# Out:
# Ratio A (F = 0.5, S2 = 35)   : 0.991
# Ratio B (F = 1  , S2 = 35)   : 0.9602
# Ratio C (F = 1.5, S2 = 35)   : 0.8356
# Ratio D (F = 0.5, S2 = 34.75): 0.921
# Ratio E (F = 1  , S2 = 34.75): 0.7554
# Ratio F (F = 1  , S2 = 34.75): 0.365
