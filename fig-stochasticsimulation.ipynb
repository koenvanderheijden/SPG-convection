# %%
include("AuxiliaryFunctions/BornModel.jl")
include("AuxiliaryFunctions/Plotting.jl")
include("AuxiliaryFunctions/NoiseAuxiliaryFunctions.jl")

import .BornModel as BM
import .Plotting as P
import .NoiseAuxiliaryFunctions as NAF

using Plots, Plots.PlotMeasures
using DifferentialEquations
using BifurcationKit, Parameters
using Statistics
using KernelDensity
# Out:
# WARNING: using Plots.wrap in module BifurcationKit conflicts with an existing identifier.
# ┌ Warning: Error requiring `KrylovKit` from `LinearSolve`
# │   exception = (LoadError("C:\\Users\\kvdhe\\.julia\\packages\\LinearSolve\\qCLK7\\ext\\LinearSolveKrylovKitExt.jl", 1, ArgumentError("Package LinearSolve does not have KrylovKit in its dependencies:\n- You may have a partially installed environment. Try `Pkg.instantiate()`\n  to ensure all packages in the environment are installed.\n- Or, if you have LinearSolve checked out for development and have\n  added KrylovKit as a dependency but haven't updated your primary\n  environment's manifest file, try `Pkg.resolve()`.\n- Otherwise you may need to report an issue with LinearSolve")), Union{Ptr{Nothing}, Base.InterpreterIP}[Ptr{Nothing} @0x000001bd33d2ab84, Ptr{Nothing} @0x000001bd33d2adfa, Ptr{Nothing} @0x00007ffa96826a24, Ptr{Nothing} @0x00007ffa9682861e, Ptr{Nothing} @0x00007ffa96827ddc, Ptr{Nothing} @0x00007ffa96827f96, Ptr{Nothing} @0x00007ffa9682920e, Ptr{Nothing} @0x00007ffa37cd2aba, Ptr{Nothing} @0x00007ffa37b23b02, Ptr{Nothing} @0x00007ffa373ddfd6, Ptr{Nothing} @0x00007ffa373ddff5, Ptr{Nothing} @0x00007ffa967f9c2a, Ptr{Nothing} @0x000001bd33d955ff, Ptr{Nothing} @0x000001bd33d95626, Ptr{Nothing} @0x00007ffa968093ca, Ptr{Nothing} @0x00007ffa96808e0a, Ptr{Nothing} @0x00007ffa96809876, Ptr{Nothing} @0x00007ffa9680a649, Base.InterpreterIP in top-level CodeInfo for LinearSolve at statement 15, Ptr{Nothing} @0x00007ffa9682772e, Ptr{Nothing} @0x00007ffa9682920e, Ptr{Nothing} @0x000001bd33d9556f, Ptr{Nothing} @0x000001bd33d95593, Ptr{Nothing} @0x00007ffa968093ca, Ptr{Nothing} @0x00007ffa96808e0a, Ptr{Nothing} @0x00007ffa96809b79, Ptr{Nothing} @0x00007ffa96809e1f, Ptr{Nothing} @0x00007ffa9680a2dc, Base.InterpreterIP in MethodInstance for Requires.err(::Any, ::Module, ::String, ::String, ::Any) at statement 4, Ptr{Nothing} @0x000001bd33d954b5, Ptr{Nothing} @0x000001bd33d954d3, Ptr{Nothing} @0x00007ffa968093ca, Ptr{Nothing} @0x00007ffa96808e0a, Ptr{Nothing} @0x00007ffa96809b79, Ptr{Nothing} @0x00007ffa96809e1f, Ptr{Nothing} @0x00007ffa9680a2dc, Base.InterpreterIP in MethodInstance for Requires.withpath(::Any, ::String) at statement 10, Ptr{Nothing} @0x000001bd33d953b9, Ptr{Nothing} @0x000001bd33d95433, Ptr{Nothing} @0x00007ffa968093ca, Ptr{Nothing} @0x00007ffa96808e0a, Ptr{Nothing} @0x00007ffa96809876, Ptr{Nothing} @0x00007ffa9680a2dc, Base.InterpreterIP in MethodInstance for Requires.listenpkg(::Any, ::Base.PkgId) at statement 3, Ptr{Nothing} @0x000001bd33d9503c, Ptr{Nothing} @0x000001bd33d95303, Ptr{Nothing} @0x00007ffa96826fd3, Ptr{Nothing} @0x00007ffa9681c430, Ptr{Nothing} @0x000001bd33d1bd82, Ptr{Nothing} @0x000001bd33d1d35d, Ptr{Nothing} @0x000001bd33d246ac, Ptr{Nothing} @0x000001bd33d2770a, Ptr{Nothing} @0x000001bd33d2a16c, Ptr{Nothing} @0x000001bd33d2a83b, Ptr{Nothing} @0x000001bd33d2adfa, Ptr{Nothing} @0x00007ffa96826a24, Ptr{Nothing} @0x00007ffa9682861e, Ptr{Nothing} @0x00007ffa96827ddc, Ptr{Nothing} @0x00007ffa96827f96, Ptr{Nothing} @0x00007ffa9682920e, Ptr{Nothing} @0x00007ffa37cd2aba, Ptr{Nothing} @0x00007ffa37b23b02, Ptr{Nothing} @0x000001bd33d5d447, Ptr{Nothing} @0x000001bd33d5d466, Ptr{Nothing} @0x00007ffa968093ca, Ptr{Nothing} @0x00007ffa96808e0a, Ptr{Nothing} @0x00007ffa96809876, Ptr{Nothing} @0x00007ffa9680a649, Base.InterpreterIP in top-level CodeInfo for Main at statement 0, Ptr{Nothing} @0x00007ffa9682772e, Ptr{Nothing} @0x00007ffa96827f96, Ptr{Nothing} @0x00007ffa9682920e, Ptr{Nothing} @0x000001bd33d5d0c9, Ptr{Nothing} @0x000001bd33d5d3da, Ptr{Nothing} @0x000001bd33d5a139, Ptr{Nothing} @0x000001bd33d5b16a, Ptr{Nothing} @0x00007ffa967f9c2a, Ptr{Nothing} @0x000001bd33d4d702, Ptr{Nothing} @0x000001bd33d57632, Ptr{Nothing} @0x000001bd33d57653, Ptr{Nothing} @0x00007ffa9680e9ce])
# └ @ Requires C:\Users\kvdhe\.julia\packages\Requires\Z8rfN\src\require.jl:51

# %%
# integration settings

spinup = 10
n_years = 5000 + spinup #5000

seed = 111
# Out:
# 111

# %%
noisevec = [0, BM.nondimensional_S(0.5), 0]

pars_F05_S35_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(35.), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(1.6), Tamp = 0,
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(0.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F05_S35_σS05 = NAF.integration(pars_F05_S35_σS05, noisevec, seed, n_years, spinup)

pars_F1_S35_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(35.), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(1.6), Tamp = 0,
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F1_S35_σS05 = NAF.integration(pars_F1_S35_σS05, noisevec, seed, n_years, spinup)

pars_F15_S35_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(35.), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(1.6), Tamp = 0,
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F15_S35_σS05 = NAF.integration(pars_F15_S35_σS05, noisevec, seed, n_years, spinup)

pars_F05_S3475_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(34.75), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(1.6), Tamp = 0,
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(0.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F05_S3475_σS05 = NAF.integration(pars_F05_S3475_σS05, noisevec, seed, n_years, spinup)

pars_F1_S3475_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(34.75), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(1.6), Tamp = 0,
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F1_S3475_σS05 = NAF.integration(pars_F1_S3475_σS05, noisevec, seed, n_years, spinup)

pars_F15_S3475_σS05 = (T2 = BM.nondimensional_T(10.), S2 = BM.nondimensional_S(34.75), T4 = BM.nondimensional_T(4.), S4 = BM.nondimensional_S(34.9), T0 = BM.nondimensional_T(1.6), Tamp = 0,
    η = 1.29e2, μ1 = 0.838,μ2 = 83.8, μ3 = 12.1, μ4 = BM.nondimensional_F(1.5), r = 0.0714, τT0 = 0, τS2 = 1, τF = 0)
output_F15_S3475_σS05 = NAF.integration(pars_F15_S3475_σS05, noisevec, seed, n_years, spinup)
# Out:
# (M_yearly = [22.959399849965152, 21.26948114843896, 20.646433547607458, 20.346095494373927, 20.26087866355955, 20.171964739044533, 20.12204362823336, 20.093471805592557, 20.079105826248142, 20.061003655179807  …  20.03032154745741, 20.031461084870536, 20.055524187535344, 20.10768787701677, 20.10638575873871, 20.11222078195741, 20.0949031250498, 20.085907784790507, 20.147121074794722, 20.137423610290917], ratio = 0.2018, below = [14, 209, 42, 6, 75, 25, 39, 21, 14, 207  …  47, 74, 15, 29, 57, 57, 30, 48, 33, 47], above = [1, 20, 10, 18, 6, 5, 6, 27, 7, 21  …  15, 10, 2, 6, 21, 34, 43, 3, 20, 10])

# %%
ylimits12 = (18, 30)
ylimits3 = (0, 0.3)
xlimits12 = (0, 0.5)
xlimits3 = (0, 30)

p_F05_S35_σS05 = NAF.plot_integration_PDF(output_F05_S35_σS05, "A", "a)", "b)", "c)", xlimits12, xlimits3, ylimits12, (0, 0.3), 0:0.1:0.3)
p_F1_S35_σS05 = NAF.plot_integration_PDF(output_F1_S35_σS05, "B ", "d)", "e)", "f)", xlimits12, xlimits3, ylimits12, (0, 0.2), 0:0.05:0.2)
p_F15_S35_σS05 = NAF.plot_integration_PDF(output_F15_S35_σS05, "C ", "g)", "h)", "i)", xlimits12, xlimits3, ylimits12, (0, 0.1), 0:0.025:0.1)
p_F05_S3475_σS05 = NAF.plot_integration_PDF(output_F05_S3475_σS05, "D ", "j)", "k)", "l)", xlimits12, xlimits3, ylimits12, (0, 0.15))
p_F1_S3475_σS05 = NAF.plot_integration_PDF(output_F1_S3475_σS05, "E ", "m)", "n)", "o)", xlimits12, xlimits3, ylimits12, (0, 0.06), 0:0.02:0.06)
p_F15_S3475_σS05 = NAF.plot_integration_PDF(output_F15_S3475_σS05, "F ", "p)", "q)", "r)", xlimits12, xlimits3, ylimits12, (0, 0.015))

plot(p_F05_S35_σS05, p_F1_S35_σS05, p_F15_S35_σS05, p_F05_S3475_σS05, p_F1_S3475_σS05, p_F15_S3475_σS05, layout = (6, 1), 
    titlefonthalign = :left,    
    titlefontsize = 14,
    size = (width = 1000, height = 1500),
    left_margin = 30px, right_margin = 20px,
    dpi = 300)

savefig("Figures/stochasticsimulation.pdf")
# Out:
# "c:\\Users\\kvdhe\\Documents\\a. Studie\\6 - MSc 2\\Thesis\\Paper\\Code\\Figures\\stochasticsimulation.pdf"

# %% [markdown]
# ## Data for table

# %%
print("Ratio A (F = 0.5, S2 = 35)   : $(output_F05_S35_σS05.ratio) \n")
print("Ratio B (F = 1  , S2 = 35)   : $(output_F1_S35_σS05.ratio) \n")
print("Ratio C (F = 1.5, S2 = 35)   : $(output_F15_S35_σS05.ratio) \n")
print("Ratio D (F = 0.5, S2 = 34.75): $(output_F05_S3475_σS05.ratio) \n")
print("Ratio E (F = 1  , S2 = 34.75): $(output_F1_S3475_σS05.ratio) \n")
print("Ratio F (F = 1  , S2 = 34.75): $(output_F15_S3475_σS05.ratio) \n")
# Out:
# Ratio A (F = 0.5, S2 = 35)   : 0.978
# Ratio B (F = 1  , S2 = 35)   : 0.915
# Ratio C (F = 1.5, S2 = 35)   : 0.684
# Ratio D (F = 0.5, S2 = 34.75): 0.791
# Ratio E (F = 1  , S2 = 34.75): 0.506
# Ratio F (F = 1  , S2 = 34.75): 0.203
